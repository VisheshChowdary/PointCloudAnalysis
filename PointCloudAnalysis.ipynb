# %%
# !git clone https://github.com/VisheshChowdary/PointCloudAnalysis.git

# %%
# %cd PointCloudAnalysis
# Out:
# Cloning into 'PointCloudAnalysis'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 30 (delta 1), reused 30 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (30/30), 6.63 KiB | 3.32 MiB/s, done.
# Resolving deltas: 100% (1/1), done.
# /content/PointCloudAnalysis
# 3dd67ad (HEAD -> main, origin/main, origin/HEAD) Update main entry and requirements

# %%
# !ls

# %%
# !pip install trimesh pyyaml tqdm

# %%
from pathlib import Path

root = Path("/kaggle/input/datasets/balraj98/modelnet40-princeton-3d-object-dataset/ModelNet40")

print(root.exists())
print(len(list(root.iterdir())))

# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))

# %%
# !rm -rf PointCloudAnalysis
# !git clone https://github.com/VisheshChowdary/PointCloudAnalysis.git
# %cd PointCloudAnalysis

# %%
# !python main.py
